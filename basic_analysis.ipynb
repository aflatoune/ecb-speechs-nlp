# %%
import pandas as pd
import os
from nltk import FreqDist
import re
from readability import Readability
import matplotlib.pyplot as plt

from utils.base_analysis import BaseAnalysis

# %%
pd.set_option('display.max_rows', None)
plt.style.use('seaborn-whitegrid')
plt.rcParams['figure.figsize'] = (13,8)

# %%
ba = BaseAnalysis('en_2006_2020')
ba.data_from_csv('processed_data.csv')

# %% [markdown]
# --------------------
# ------------------
# --------------
#
# Get words count per speech (raw speech or processed speech):

# %%
ba.count_word()
# Out:
#                   date  counts_raw_speech  counts_processed_speech
# 0     10 December 2020               2306                     1118
# 1      29 October 2020               1683                      863
# 2    10 September 2020               1738                      856
# 3         16 July 2020               1823                      902
# 4          4 June 2020               1800                      861
# 5        30 April 2020               2005                      968
# 6        12 March 2020               1716                      820
# 7      23 January 2020               1342                      685
# 8     12 December 2019               1335                      666
# 9      24 October 2019               1152                      588
# 10   12 September 2019               1552                      759
# 11        25 July 2019               1184                      615
# 12         6 June 2019               1419                      673
# ...

# %% [markdown]
# Get top words:

# %%
ba.get_top_words(n_words=25, processed=True)

# %% [markdown]
# Assess the readability of the speechs:

# %%
ba.graph_readability()
